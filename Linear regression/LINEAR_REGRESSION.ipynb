# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-1d754bf7-913c-4bb9-b4bc-ec4117064d08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d754bf7-913c-4bb9-b4bc-ec4117064d08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Gold_Price.csv to Gold_Price.csv

# %%
import pandas as pd
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
dataset= pd.read_csv(io.BytesIO(file['Gold_Price.csv']))

# %%
Xset = dataset.drop(['USO_High','USO_Low'],axis=1)
Yset = dataset['USO_Low']

# %%
dataset.isnull().sum()
# Out:
# Open             0
# High             0
# Low              0
# Close            0
# Adj Close        0
#                 ..
# USO_High         0
# USO_Low          0
# USO_Close        0
# USO_Adj Close    0
# USO_Volume       0
# Length: 80, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(Xset, Yset, test_size = 0.2, random_state=101)

# %%
sns.heatmap(dataset, vmin=0, vmax=1, center=10) 
plt.show()

# %%
linear = LinearRegression()
linear.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
grp = sns.regplot(x='OF_Price', y='OF_Volume', data=dataset, color='green') 
plt.title("Predicting Gold Price")
# Out:
# Text(0.5, 1.0, 'Predicting Gold Price')

# %%
Y_pred = linear.predict(X_test)

# %%
plt.figure(figsize=(10, 5))

# %%
error_score = metrics.r2_score(Y_test, Y_pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9999349316371641

# %%
Y_test = list(Y_test)

# %%
plt.figure(figsize=(25,5))
plt.plot(Y_test, color='green', label = 'Actual Value')
plt.plot(Y_pred, color='grey', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GOLD Price')
plt.legend()
plt.show()
